# %% [raw]
# Okay task is to do data anonymization:
#
# but on what data?
# - medical records especially the one in JSON format
# - in medical records i should anonymize data such as,
#     1. General information: names, addresses, phone numbers, emails.
#     2. Medical information: patient names, patient IDs, dates of birth, specific injury details, witness statements etc...
#
#
# - the technique which i apply should satisfy two conditions:
#     1. Keeping facts similar:
#     When i change the details in a story to protect privacy, i want to keep the overall idea the same.
#     For example, if the original story is about a car accident, the anonymized version should still be about a car accident,
#     not suddenly become a story about a skiing incident.
#
#     2. Matching information across documents:
#     If i change a piece of information, like a phone number, i need to use the same new phone number everywhere it appears in the case files.

# %% [raw]
# techniques USed:
# Entity Recognition and Replacement: Use Named Entity Recognition (NER) to identify entities (such as names, locations, dates) and replace them with synthetic but contextually appropriate counterparts.
# so how did i implement? using SpaCy to detect all the entites within textual fields.

# %% [raw]
# Process:
# -the script creates a deep copy of the original data to avoid altering it.
# -it then traverses the copied data, anonymizing fields as defined.
# -at last, it prints out the anonymized JSON data in a readable format.

# %% [raw]
# anonimization funcs:
# anonymize_field: replaces the specific fields with fake data based on their type.actually it checks if the original value has already been anonymized to maintain some consistency.
# anonymize_text: uses spaCy's NER to identify entities within text fields and replaces them with fake data.
# traverse_and_anonymize: recursively traverses the json object, anonymizing fields based on definitions.

# %% [raw]
# also used mapping dictionaries:
# mappings ensures that the same original value is replaced with the same fake value throughout the dataset, maintaining consistency.

# %% [raw]
# and also kept some fields such as date filed, report number, type of incident as exact values, but still i will anonymize it if you dont want any exact values from the data

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 279.3 kB/s eta 0:00:46
#      --------------------------------------- 0.1/12.8 MB 774.0 kB/s eta 0:00:17
#       -------------------------------------- 0.2/12.8 MB 888.4 kB/s eta 0:00:15
#      - -------------------------------------- 0.3/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/12.8 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.8 MB 1.4 MB/s eta 0:00:09
#      -- ------------------------------------- 0.6/12.8 MB 1.4 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.8 MB 1.6 MB/s eta 0:00:08
#      --- ------------------------------------ 1.0/12.8 MB 1.8 MB/s eta 0:00:07
#      --- ------------------------------------ 1.2/12.8 MB 2.0 MB/s eta 0:00:06
#      --- ------------------------------------ 1.3/12.8 MB 1.9 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.4/12.8 MB 2.0 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.5/12.8 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.7/12.8 MB 2.2 MB/s eta 0:00:06
#      ------ --------------------------------- 2.0/12.8 MB 2.3 MB/s eta 0:00:05
#      ------ --------------------------------- 2.2/12.8 MB 2.5 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/12.8 MB 2.5 MB/s eta 0:00:05
#      -------- ------------------------------- 2.6/12.8 MB 2.7 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 2.7 MB/s eta 0:00:04
#      -------- ------------------------------- 2.7/12.8 MB 2.6 MB/s eta 0:00:04
#      --------- ------------------------------ 2.9/12.8 MB 2.7 MB/s eta 0:00:04
#      --------- ------------------------------ 3.2/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.2/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.3/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 2.7 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.5/12.8 MB 2.6 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.7/12.8 MB 2.6 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.8/12.8 MB 2.7 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.8/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------ --------------------------- 3.9/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------- -------------------------- 4.2/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------- -------------------------- 4.3/12.8 MB 2.7 MB/s eta 0:00:04
#      ------------- -------------------------- 4.4/12.8 MB 2.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.8 MB 2.7 MB/s eta 0:00:03
#      --------------- ------------------------ 4.9/12.8 MB 2.8 MB/s eta 0:00:03
#      --------------- ------------------------ 5.1/12.8 MB 2.8 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.3/12.8 MB 2.9 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.6/12.8 MB 2.9 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.7/12.8 MB 2.9 MB/s eta 0:00:03
#      ------------------ --------------------- 5.9/12.8 MB 3.0 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.8 MB 2.9 MB/s eta 0:00:03
#      ------------------- -------------------- 6.2/12.8 MB 3.0 MB/s eta 0:00:03
#      -------------------- ------------------- 6.5/12.8 MB 3.0 MB/s eta 0:00:03
#      -------------------- ------------------- 6.7/12.8 MB 3.1 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 3.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.2/12.8 MB 3.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.8 MB 3.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.8/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------- -------------- 8.3/12.8 MB 3.3 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 3.3 MB/s eta 0:00:02
#      -------------------------- ------------- 8.6/12.8 MB 3.2 MB/s eta 0:00:02
#      --------------------------- ------------ 8.8/12.8 MB 3.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 3.3 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.1/12.8 MB 3.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.3/12.8 MB 3.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.6/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 3.4 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 3.5 MB/s eta 0:00:01
#      -------------------------------- ------- 10.6/12.8 MB 3.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 3.7 MB/s eta 0:00:01
#      --------------------------------- ------ 10.9/12.8 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.8 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in d:\cursor\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.12)
# Requirement already satisfied: jinja2 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\cursor\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in d:\cursor\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\cursor\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\cursor\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\cursor\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\cursor\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\cursor\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\cursor\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\cursor\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in d:\cursor\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in d:\cursor\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\cursor\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\cursor\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in d:\cursor\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in d:\cursor\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\cursor\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in d:\cursor\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\cursor\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\cursor\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\cursor\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.0)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import json
import copy
from faker import Faker
import spacy
from collections import defaultdict

fake = Faker()
nlp = spacy.load("en_core_web_sm")

#json data from synthetic data in rag channel
data_json = [
    {
        "seriousness": 5,
        "police_record": {
            "report_number": 40995708,
            "date_filed": "2024-07-21",
            "reporting_officer": "Lori Johns",
            "incident_type": "Vehicle Collision",
            "location": "36913 Atkinson Parks",
            "description": "Two-vehicle collision involving Nicole Bush. Moderate-speed collision (approximately 27 mph). Significant damage to vehicles.",
            "witness_statements": [
                "Kenneth Green: 'Time health to get face dream accept.'",
                "Sean Mccarthy: 'Miss rather woman until leg produce road.'"
            ]
        },
        "information_sheet": {
            "full_name": "Nicole Bush",
            "date_of_birth": "1960-09-21",
            "address": "00410 James Falls Apt. 816\nJacobton, FM 68526",
            "phone_number": "382.916.1238x3973",
            "email": "hthompson@example.com",
            "occupation": "Video editor",
            "employer": "Williams LLC",
            "insurance_provider": "Matthews-Kelley",
            "policy_number": 6204211294,
            "accident_date": "2024-07-21 00:00",
            "accident_location": "65525 Gentry Ports Suite 328"
        },
        "medical_record": {
            "patient_name": "Nicole Bush",
            "patient_id": 69636128,
            "date_of_birth": "1960-09-21",
            "gender": "Female",
            "accident_date": "2024-07-21 00:00",
            "injuries": [
                "Mild concussion",
                "Moderate concussion",
                "Sprained ankle"
            ]
        }
    }
]

#defining the pii fields that require some direct anonymization
PII_FIELDS = {
    "full_name": "name",
    "date_of_birth": "date_of_birth",
    "address": "address",
    "phone_number": "phone_number",
    "email": "email",
    "patient_name": "name",
    "patient_id": "numeric_id",
    "reporting_officer": "name",
    "location": "address",
    "accident_location": "address",
}

# text feilds that require ner based anonymization
TEXT_FIELDS = [
    ("police_record", "description"),
    ("police_record", "witness_statements")
]

#mapping dictionaries to maintain some consistency
mappings = defaultdict(dict)

def anonymize_field(original_value, field_type):
    
    if original_value in mappings[field_type]:
        return mappings[field_type][original_value]
    else:
        if field_type == "name":
            fake_value = fake.name()
        elif field_type == "address":
            fake_value = fake.address().replace("\n", ", ")
        elif field_type == "phone_number":
            fake_value = fake.phone_number()
        elif field_type == "email":
            fake_value = fake.email()
        elif field_type == "date_of_birth":
            fake_value = fake.date_of_birth(minimum_age=18, maximum_age=90).isoformat()
        elif field_type == "numeric_id":
            fake_value = fake.unique.random_number(digits=8, fix_len=True)
        else:
            fake_value = "ANON"
        mappings[field_type][original_value] = fake_value
        return fake_value

def anonymize_text(text):
    doc = nlp(text)
    anonymized_text = text
    for ent in reversed(doc.ents):  #reverse to replace from the end to not mess up indices
        if ent.label_ in ["PERSON", "GPE", "ORG", "DATE", "ADDRESS"]:
            original = ent.text
            if ent.label_ == "PERSON":
                fake_replacement = anonymize_field(original, "name")
            elif ent.label_ == "GPE" or ent.label_ == "ADDRESS":
                fake_replacement = anonymize_field(original, "address")
            elif ent.label_ == "ORG":
                fake_replacement = fake.company()
            elif ent.label_ == "DATE":
                fake_replacement = fake.date()
            else:
                fake_replacement = "ANON"
            #replacing the entity in the text
            anonymized_text = anonymized_text[:ent.start_char] + fake_replacement + anonymized_text[ent.end_char:]
    return anonymized_text

def traverse_and_anonymize(obj):
    """
    recursively traversing the JSON object and anonymizing fields to handle wide variety of data structures that the json represents
    """
    if isinstance(obj, list):
        return [traverse_and_anonymize(item) for item in obj]
    elif isinstance(obj, dict):
        new_obj = {}
        for key, value in obj.items():
            #Direct anonymization for specific PII fields
            if key in PII_FIELDS:
                field_type = PII_FIELDS[key]
                new_value = anonymize_field(value, field_type)
                new_obj[key] = new_value
            elif key == "accident_date":
                #eplacing with just the year or month
                new_obj[key] = fake.date(pattern="%Y-%m-%d")
            #handling the text fields with NERased anonymization
            elif (key, ) in TEXT_FIELDS or any(key == tf[1] and key in parent for tf in TEXT_FIELDS for parent in obj.keys()):
                parent_key = list(obj.keys())[0] if len(obj.keys()) > 0 else ""
                if isinstance(value, str):
                    new_obj[key] = anonymize_text(value)
                elif isinstance(value, list):
                    new_obj[key] = [anonymize_text(item) if isinstance(item, str) else item for item in value]
                else:
                    new_obj[key] = value
            #recursively handling nested dictionary orlists
            elif isinstance(value, dict) or isinstance(value, list):
                new_obj[key] = traverse_and_anonymize(value)
            else:
                new_obj[key] = value
        return new_obj
    else:
        return obj

#deep copy of the data
anonymized_data = traverse_and_anonymize(copy.deepcopy(data_json))

#output
print("Anonymized JSON Data:")
print(json.dumps(anonymized_data, indent=2))
# Out:
# Anonymized JSON Data:
# [
#   {
#     "seriousness": 5,
#     "police_record": {
#       "report_number": 40995708,
#       "date_filed": "2024-07-21",
#       "reporting_officer": "Benjamin Jefferson",
#       "incident_type": "Vehicle Collision",
#       "location": "5724 Gomez Way Apt. 399, Maloneville, PR 18446",
#       "description": "Two-vehicle collision involving Dale Nguyen. Moderate-speed collision (approximately 27 mph). Significant damage to vehicles.",
#       "witness_statements": [
#         "Sean Brown 'Time health to get face dream accept.'",
#         "Kelsey Moore: 'Jonathan Ibarra rather woman until leg produce road.'"
#       ]
#     },
#     "information_sheet": {
#       "full_name": "Dale Nguyen",
#       "date_of_birth": "1957-06-16",
#       "address": "190 Thomas Plains, Coleville, ME 39617",
#       "phone_number": "001-611-867-5624",
#       "email": "bensontimothy@example.net",
#       "occupation": "Video editor",
#       "employer": "Williams LLC",
#       "insurance_provider": "Matthews-Kelley",
#       "policy_number": 6204211294,
#       "accident_date": "1991-07-12",
#       "accident_location": "7146 Donna Parkways, Francisport, OR 14619"
#     },
#     "medical_record": {
#       "patient_name": "Dale Nguyen",
#       "patient_id": 82610213,
#       "date_of_birth": "1957-06-16",
#       "gender": "Female",
#       "accident_date": "2014-09-25",
#       "injuries": [
#         "Mild concussion",
#         "Moderate concussion",
#         "Sprained ankle"
#       ]
#     }
#   }
# ]
